# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

# %%
import urllib.request

user_agent = 'Mozilla/5.0 (Windows; U; Windows NT 5.1; en-US; rv:1.9.0.7) Gecko/2009021910 Firefox/3.0.7'

url = "https://www.fastfoodmenuprices.com/shake-shack-prices/"
headers={'User-Agent':user_agent,} 

request=urllib.request.Request(url,None,headers) #The assembled request
response = urllib.request.urlopen(request)
html = response.read() # The data u need

# %%
soup = BeautifulSoup(html, 'lxml')
type(soup)
title = soup.title
#print(title)
# Print out the text
text = soup.get_text()
print(soup.text)
# Out:
# Shake Shack Prices - Fast Food Menu Prices {"@context":"https:\/\/schema.org","@type":"BreadcrumbList","itemListElement":[{"@type":"ListItem","position":1,"item":{"@id":"https:\/\/www.fastfoodmenuprices.com\/","name":"Home"}},{"@type":"ListItem","position":2,"item":{"@id":"https:\/\/www.fastfoodmenuprices.com\/shake-shack\/","name":"Shake Shack Prices"}}]} .cptch_block label{word-wrap:break-word}.cptch_block br{display:none!important}.cptch_label:hover{cursor:pointer}form input.cptch_input{padding-left:8px;padding-right:8px}.cptch_whitelist_message{font-style:italic;color:green;font-weight:normal!important}.cptch_block{display:block!important;width:100%;max-width:100%;box-sizing:border-box;word-spacing:normal!important;text-align:left}.cptch_title{display:block;word-wrap:break-word;padding-bottom:5px;clear:both}.cptch_wrap{display:table-row!important;position:relative;clear:both}.cptch_label,.cptch_reload_button_wrap{display:table-cell;margin:5px 0!important;vertical-align:middle;line-height:1}.cptch_time_limit_notice{display:none;color:red;font-size:12px}.cptch_span{display:inline-block;vertical-align:middle;line-height:1;position:relative}.cptch_recognition .cptch_span{margin-right:2px}.rtl .cptch_recognition .cptch_span{margin-right:0;margin-left:2px}.cptch_img{width:40px;max-width:40px!important;height:40px;top:0;z-index:1}.cptch_reload_button{width:2rem;height:2rem;font-size:2rem;margin:0 15px;vertical-align:text-bottom}.cptch_reload_button:before{vertical-align:text-bottom}.cptch_recognition .cptch_images_wrap{display:block;margin-bottom:3px}.rtl .cptch_block{direction:rtl;text-align:right}@media only screen and (max-width:782px){.cptch_reload_button{width:48px;height:48px;font-size:48px}}.cptch_ajax_wrap{color:red}.cptch_img:hover{cursor:default;position:relative;z-index:10;-webkit-transition:300ms ease-in-out;-moz-transition:300ms ease-in-out;-o-transition:300ms ease-in-out;transition:300ms ease-in-out}.cptch_left:hover{-webkit-transform:translateX(100%) scale(3,3);-moz-transform:translateX(100%) scale(3,3);-o-transform:translateX(100%) scale(3,3);-ms-transform:translateX(100%) scale(3,3);transform:translateX(100%) scale(3,3)}.cptch_right:hover{-webkit-transform:translateX(-100%) scale(3,3);-moz-transform:translateX(-100%) scale(3,3);-ms-transform:translateX(-100%) scale(3,3);-o-transform:translateX(-100%) scale(3,3);transform:translateX(-100%) scale(3,3)}.cptch_center:hover{-webkit-transform:scale(3,3);-moz-transform:scale(3,3);-o-transform:scale(3,3);-ms-transform:scale(3,3);transform:scale(3,3)}.cptch_reload_button:hover{cursor:pointer;opacity:.7}.cptch_reload_button.cptch_active{opacity:.7;animation:cptch_rotation 800ms infinite linear;-webkit-animation:cptch_rotation 800ms infinite linear}@-webkit-keyframes cptch_rotation{0%{-webkit-transform:rotate(0deg)}100%{-webkit-transform:rotate(359deg)}}@-moz-keyframes cptch_rotation{0%{-webkit-transform:rotate(0deg)}100%{-webkit-transform:rotate(359deg)}}@-o-keyframes cptch_rotation{0%{-webkit-transform:rotate(0deg)}100%{-webkit-transform:rotate(359deg)}}@keyframes cptch_rotation{0%{transform:rotate(0deg)}100%{transform:rotate(359deg)}}div.wpcf7{margin:0;padding:0}div.wpcf7 .screen-reader-response{position:absolute;overflow:hidden;clip:rect(1px,1px,1px,1px);height:1px;width:1px;margin:0;padding:0;border:0}div.wpcf7-response-output{margin:2em .5em 1em;padding:.2em 1em;border:2px solid red}div.wpcf7-mail-sent-ok{border:2px solid #398f14}div.wpcf7-mail-sent-ng,div.wpcf7-aborted{border:2px solid red}div.wpcf7-spam-blocked{border:2px solid #ffa500}div.wpcf7-validation-errors,div.wpcf7-acceptance-missing{border:2px solid #f7e700}.wpcf7-form-control-wrap{position:relative}span.wpcf7-not-valid-tip{color:red;font-size:1em;font-weight:400;display:block}.use-floating-validation-tip span.wpcf7-not-valid-tip{position:absolute;top:20%;left:20%;z-index:100;border:1px solid red;background:#fff;padding:.2em .8em}span.wpcf7-list-item{display:inline-block;margin:0 0 0 1em}span.wpcf7-list-ite ...
# (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
# ga('create', 'UA-39816079-1', 'auto');
# ga('send', 'pageview');  window._taboola = window._taboola || [];
# _taboola.push({article:'auto'});
# !function (e, f, u) {
# e.async = 1;
# e.src = u;
# f.parentNode.insertBefore(e, f);
# }(document.createElement('script'),
# document.getElementsByTagName('script')[0],
# 'https://cdn.taboola.com/libtrc/fastfoodmenuprices/loader.js' );  (adsbygoogle = window.adsbygoogle || []).push({
# google_ad_client: "ca-pub-2225482417208543",
# enable_page_level_ads: true
# });  var googletag = googletag || {};
# googletag.cmd = googletag.cmd || []; googletag.cmd.push(function() {
# var width = window.outerWidth || document.documentElement.clientWidth || document.body.clientWidth;
# if (width < 340) {
# googletag.defineSlot('/21552082/FFMP_LISTING_TOP', [300, 250], 'div-gpt-ad-1497466115329-0').addService(googletag.pubads());
# googletag.defineSlot('/21552082/FFMP_LISTING_BOTTOM', [300, 250], 'div-gpt-ad-1497466115329-1').addService(googletag.pubads());
# } else if (width < 860) {
# googletag.defineSlot('/21552082/FFMP_LISTING_TOP', [336, 280], 'div-gpt-ad-1497466115329-0').addService(googletag.pubads());
# googletag.defineSlot('/21552082/FFMP_LISTING_BOTTOM', [336, 280], 'div-gpt-ad-1497466115329-1').addService(googletag.pubads());
# } else if (width < 1024) {
# googletag.defineSlot('/21552082/FFMP_LISTING_TOP', [336, 280], 'div-gpt-ad-1497466115329-0').addService(googletag.pubads());
# googletag.defineSlot('/21552082/FFMP_LISTING_BOTTOM', [336, 280], 'div-gpt-ad-1497466115329-1').addService(googletag.pubads());
# googletag.defineSlot('/21552082/FFMP_SIDEBAR_160x600', [160, 600], 'div-gpt-ad-1497466115329-2').addService(googletag.pubads());
# googletag.defineSlot('/21552082/FFMP_HOME_300x600_TOP', [300, 600], 'div-gpt-ad-1497466115329-3').addService(googletag.pubads());
# googletag.defineSlot('/21552082/FFMP_HOME_300x600_MID', [300, 600], 'div-gpt-ad-1497466115329-4').addService(googletag.pubads());
# }
# else {
# googletag.defineSlot('/21552082/FFMP_LISTING_TOP', [336, 280], 'div-gpt-ad-1497466115329-0').addService(googletag.pubads());
# googletag.defineSlot('/21552082/FFMP_LISTING_BOTTOM', [336, 280], 'div-gpt-ad-1497466115329-1').addService(googletag.pubads());
# googletag.defineSlot('/21552082/FFMP_SIDEBAR_160x600', [300, 600], 'div-gpt-ad-1497466115329-2').addService(googletag.pubads());
# googletag.defineSlot('/21552082/FFMP_HOME_300x600_TOP', [300, 600], 'div-gpt-ad-1497466115329-3').addService(googletag.pubads());
# googletag.defineSlot('/21552082/FFMP_HOME_300x600_MID', [300, 600], 'div-gpt-ad-1497466115329-4').addService(googletag.pubads());
# }
# googletag.enableServices();
# });  Skip to contentFast Food Menu Prices   HomeFast Food PricesAmy’s Drive ThroughApplebee’sArby’sBaskin-RobbinsBob Evans FarmhouseBojangles’Bonefish GrillBurger KingCaptain D’sCheckersCheddar’sChick-fil-AChili’sChipotleChurch’s ChickenCold Stone CreameryCracker BarrelCulver’sDairy QueenDel TacoDomino’sDunkin’ DonutsEl Pollo LocoFirehouse SubsFive GuysFuddruckersHardee’sHootersIHOPIn-N-OutJack in the BoxJimmy John’sKFCKrispy KremeLittle CaesarsLong John Silver’sMcDonald’sOlive GardenOutback SteakhousePanda ExpressPanera BreadP.F. Chang’sPapa John’sPapa Murphy’sPei WeiPizza HutPollo TropicalPopeyesQdobaQuiznosRaising Cane’sRally’sRed LobsterRed RobinSonicStarbucksSteak ‘n ShakeSubwayTaco BellTexas RoadhouseTim HortonsWendy’sWhataburgerWhite CastleWingstopZaxby’sSecret MenusApplebee’s Secret MenuBurger King Secret MenuChipotle Secret MenuFive Guys Secret MenuIn-N-Out Secret MenuKFC Secret MenuTaco Bell Secret MenuSonic Secret MenuStarbucks Secret MenuSubway Secret MenuWhataburger Secret MenuWendy’s Secret MenuAll Restaurants   Search for:     You are here: Home > Shake Shack Prices This website is not associated with Shake Shack  Shake Shack Prices Shake Shack is a regional fast food restaurant chain serving burgers, hot dogs, french fries, shakes and frozen custard. Shake Shack prices are more expensive than the average fast food restaurant, but that’s partially because most locations are located in the New York City region.Shake Shack offers many different types of foods such as burgers, hand-cut fries, frozen custard, chocolate, drinks, beer, and wine.Below are the latest Shake Shack menu prices.  googletag.cmd.push(function() { googletag.display("div-gpt-ad-1497466115329-0"); });     (adsbygoogle = window.adsbygoogle || []).push({});     (adsbygoogle = window.adsbygoogle || []).push({}); View Estimated Prices in Your StateSelect StateAlabamaAlaskaArizonaArkansasCaliforniaColoradoConnecticutDelawareDistrict of ColumbiaFloridaGeorgiaHawaiiIdahoIllinoisIndianaIowaKansasKentuckyLouisianaMaineMarylandMassachusettsMichiganMinnesotaMississippiMissouriMontanaNebraskaNevadaNew HampshireNew JerseyNew MexicoNew YorkNorth CarolinaNorth DakotaOhioOklahomaOregonPennsylvaniaRhode IslandSouth CarolinaSouth DakotaTennesseeTexasUtahVermontVirginiaWashingtonWest VirginiaWisconsinWyomingResetFoodSizePriceBurgersShackBurgerSingle$5.29ShackBurgerDouble$8.09SmokeShackSingle$6.84SmokeShackDouble$9.64‘Shroom Burger (Vegetarian)$6.99Shack Shack$9.59HamburgerSingle$4.29HamburgerDouble$6.59Add Bacon$1.55ChickenChick’n Shack$6.29Flat-Top DogsShack-cago Dog$4.25Hot Dog$3.25Chicken Dog$4.50Crinkle Cut FriesFries$2.99Cheese Fries$3.99Frozen CustardShakes – Vanilla, Chocolate, Caramel, Black & White, Strawberry, Peanut Butter or Coffee Fair Shake$5.29Make It Malted$0.50Add Whipped Cream$0.50Shake of The Week$5.59Floats – Root Beer, Purple Cow or Creamsicle$5.29Cup or ConeSingle Dip$3.59Cup or ConeDouble Dip$4.59Pint To Go$5.99ConcretesSingle$4.59ConcretesDouble$6.79Design Your Own ConcreteSingle$3.59Design Your Own ConcreteDouble$4.79Mix-Ins$0.60DrinksShack-Made LemonadeRegular$2.80Shack-Made LemonadeLarge$3.55Organic Fresh Brewed Iced TeaRegular$2.30Organic Fresh Brewed Iced TeaLarge$2.80Fifty/FiftyRegular$2.55Fifty/FiftyLarge$3.30Fountain SodaRegular$2.30Fountain SodaLarge$2.80Draught Root BeerRegular$2.80Draught Root BeerLarge$3.55Organic Apple JuiceRegular (6.75 oz.)$1.90Bottled WaterRegular (710 ml.)$2.40Stumptown Cold Brewed Coffee$4.75BeerShackMeister AleDraught (16 oz.)$5.69ShackMeister AleDraught (24 oz.)$7.69WineShack Red or WhiteShack WhiteGlass (6 oz.)$7.89Shack RedGlass (6 oz.)$8.89Shack WhiteBottle (750 ml.)$28.39Shack RedBottle (750 ml.)$31.99WoofTreats For PetsPooch-Ini$3.99Bag O’ Bones5 Pc.$7.99 googletag.cmd.push(function() { googletag.display("div-gpt-ad-1497466115329-1"); }); Shake Shack is a fairly new company, having been founded in 2004 in New York City, by Danny Meyer. Before that, Danny opened up a hot dog cart, which ended up bein ...
# _taboola.push({
# mode: 'thumbnails-ba1-clone',
# container: 'taboola-below-article-thumbnails',
# placement: 'Below Article Thumbnails',
# target_type: 'mix'
# }); Join the Conversation 3 Comments    Shirley Aamidor says:   February 1, 2015 at 5:57 pm  For these prices, go to a decent, local restaurant. Why pay high prices for a fast-food menu.Reply     john says:   December 26, 2015 at 9:16 pm  shake shack sucksReply     Blob says:   January 17, 2018 at 11:50 am  Sister works there gets 60% off soo hahaReply Leave a Reply Cancel replyCommentName * Email * (function( timeout ) {
# setTimeout(
# function() {
# var notice = document.getElementById("cptch_time_limit_notice_20");
# if ( notice )
# notice.style.display = "block";
# },
# timeout
# );
# })(120000); Time limit is exhausted. Please reload CAPTCHA. seven  −  four  =      .hide-if-no-js { display: none !important; }      NewsletterGet the latest fast food coupons, news, and tips every month to your email.       Thank you for joining our mailing list!We respect your privacy var _bmxq = _bmxq || []; _bmxq.push(['_setupForm', 'form[f0fc4977-3814-4f21-9038-4a243ebbfd1c]']);  Headlines What’s New at Starbucks in 2018? Great Choices for Late Night Fast Food Coffee, Meet Beer: Harpoon and Dunkin’ Donuts Join Forces This Fall To Create A Coffee Beer Healthy Choices At Cold Stone Creamery Red Robin Launches Hop-Salt Fries Fast Food Chicken Prices from KFC, Popeyes, and Chick-fil-A McDonald’s and Starbucks Join Forces To Eliminate Plastic Straws Here’s How We Like McDonald’s Maple Bacon Dijon Signature Crafted Sandwiches Low Sodium Fast Food: Your Best Options Taco Bell vs Del Taco – Pros and Cons of Each Food Chain  googletag.cmd.push(function() { googletag.display('div-gpt-ad-1497466115329-2'); }); The Most Popular Fast Food PricesArby’sBurger KingCarl’s Jr.CheckersChick-fil-AChipotleChurch’s ChickenDairy QueenDomino’sDunkin’ DonutsFive GuysHardee’sJack in the BoxJimmy John’sKFCKrispy KremeLittle CaesarsMcDonald’sPanda ExpressPanera BreadPizza HutPopeyesRally’sSonicStarbucksSubwayTaco BellWendy’sWhataburgerWhite CastleView All RestaurantsPrices and selections offered may vary by location. All prices provided on this website are averaged and should only be used as estimates.Company trademarks are the property of the respective company and their presence does not necessarily mean that FastFoodMenuPrices.com has an affiliation with the company.About UsPrivacy PolicyContact UsFast Food Menu PricesDon't Be Surprised By The Cost of Fast Food   LIKE US       FOLLOW US   Copyright © 2018 Fast Food Menu Prices. All Rights Reserved.Fast Food Menu Prices   HomeFast Food PricesA–CAmy’s Drive ThroughApplebee’sArby’sBaskin-RobbinsBob Evans FarmhouseBojangles’Bonefish GrillBurger KingCaptain D’sCheckersCheddar’sChick-fil-AChili’sChipotleChurch’s ChickenCold Stone Creamery BackC–HCracker BarrelCulver’sDairy QueenDel TacoDomino’sDunkin’ DonutsEl Pollo LocoFirehouse SubsFive GuysFuddruckersHardee’sHooters BackI–PIHOPIn-N-OutJack in the BoxJimmy John’sKFCKrispy KremeLittle CaesarsLong John Silver’sMcDonald’sOlive GardenOutback SteakhousePanda ExpressPanera Bread BackP–SP.F. Chang’sPapa John’sPapa Murphy’sPei WeiPizza HutPollo TropicalPopeyesQdobaQuiznosRaising Cane’sRally’sRed LobsterRed RobinSonic BackS-ZStarbucksSteak ‘n ShakeSubwayTaco BellTexas RoadhouseTim HortonsWendy’sWhataburgerWhite CastleWingstopZaxby’s Back BackSecret MenusApplebee’s Secret MenuBurger King Secret MenuChipotle Secret MenuFive Guys Secret MenuIn-N-Out Secret MenuKFC Secret MenuTaco Bell Secret MenuSonic Secret MenuStarbucks Secret MenuSubway Secret MenuWhataburger Secret MenuWendy’s Secret Menu BackAll Restaurants (function(s,u,m,o,j,v){j=u.createElement(m);v=u.getElementsByTagName(m)[0];j.async=1;j.src=o;j.dataset.sumoSiteId='711f7e083ce5aba66328cdc578ce2ba6a4cbb4df84541ccaec212deba7d3a588';j.dataset.sumoPlatform='wordpress';v.parentNode.insertBefore(j,v)})(window,document,'script','//load.sumo.com/'); var ajaxurl = "https://www.fastfoodmenuprices.com/wp-admin/admin-ajax.php";
# function sumo_add_woocommerce_coupon(code) {
# jQuery.post(ajaxurl, {
# action: 'sumo_add_woocommerce_coupon',
# code: code,
# });
# }
# function sumo_remove_woocommerce_coupon(code) {
# jQuery.post(ajaxurl, {
# action: 'sumo_remove_woocommerce_coupon',
# code: code,
# });
# }
# function sumo_get_woocommerce_cart_subtotal(callback) {
# jQuery.ajax({
# method: 'POST',
# url: ajaxurl,
# dataType: 'html',
# data: {
# action: 'sumo_get_woocommerce_cart_subtotal',
# },
# success: function(subtotal) {
# return callback(null, subtotal);
# },
# error: function(err) {
# return callback(err, 0);
# }
# });
# } /*  */
# var wpcf7 = {"apiSettings":{"root":"https:\/\/www.fastfoodmenuprices.com\/wp-json\/contact-form-7\/v1","namespace":"contact-form-7\/v1"},"recaptcha":{"messages":{"empty":"Please verify that you are not a robot."}},"cached":"1"};
# /*  */ /*  */
# var cdv8Gdpr = {"popupBackgroundColor":"#edeff5","popupTextColor":"#838391","btnBackgroundColor":"#4b81e8","bannerMessage":"This website uses cookies to ensure you get the best experience on our website.","dismissBtnText":"Accept!","policyLinkText":"Read Our Privacy Policy","policyLinkTextURL":"https:\/\/www.fastfoodmenuprices.com\/privacy-policy"};
# var ubermenu_data = {"remove_conflicts":"on","reposition_on_load":"off","intent_delay":"300","intent_interval":"100","intent_threshold":"7","scrollto_offset":"50","scrollto_duration":"1000","responsive_breakpoint":"959","accessible":"on","retractor_display_strategy":"responsive","touch_off_close":"on","submenu_indicator_close_mobile":"on","collapse_after_scroll":"on","v":"3.4.1.1","configurations":["main"],"ajax_url":"https:\/\/www.fastfoodmenuprices.com\/wp-admin\/admin-ajax.php","plugin_url":"https:\/\/www.fastfoodmenuprices.com\/wp-content\/plugins\/ubermenu\/","disable_mobile":"off","prefix_boost":"","aria_role_navigation":"off","aria_expanded":"off","aria_hidden":"off","aria_controls":"","aria_responsive_toggle":"off","icon_tag":"i","theme_locations":{"primary":"Primary Menu","shiftnav":"ShiftNav [Main]"}};
# var shiftnav_data = {"shift_body":"off","shift_body_wrapper":"","lock_body":"on","lock_body_x":"off","open_current":"off","collapse_accordions":"off","scroll_panel":"on","breakpoint":"860","v":"1.6.3","touch_off_close":"on","scroll_offset":"100","disable_transforms":"off"};
# var cptch_vars = {"nonce":"a8f3521804","ajaxurl":"https:\/\/www.fastfoodmenuprices.com\/wp-admin\/admin-ajax.php","enlarge":"0"};
# /*  */  window._taboola = window._taboola || [];
# _taboola.push({flush: true});
# window.lazyLoadOptions = {
# threshold: 50
# };
